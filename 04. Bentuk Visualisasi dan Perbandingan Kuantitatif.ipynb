# %% [markdown]
# Pada materi-materi sebelumnya telah di perkenalkan tentang pondasi-pondasi visualisasi. Dari sekarang dan ke depan materi akan lebih advance lagi, pertama akan di perkenalkan beberapa bentuk visualisasi lainnya (sebelumnya telah di pelajari lineplot), kemudian akan di tunjukan kegunaannya untuk perbandingan kuantitatif.
#
# Langsung saja. beberapa bentuk visualisasi yang akan di perkenalkan adalah :
#
# Bar Chart
# Scatter Plot
# Histogram
# Akan di gunakan data tentang penjualan video games dalam satuan juta dollar, yang mana filenya bisa di download disini.
#
# [vgsales.csv](https://blog.sanbercode.com/wp-content/uploads/2020/04/vgsales.csv)

# %%
import pandas as pd
df = pd.read_csv('https://drive.google.com/uc?id=1VdPQMY0LRgJhEPzCaGs0poAYDpAds--F')
df

# %%
data = df['Genre'].value_counts()
data
# Out:
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %%
data.index
# Out:
# Index(['Action', 'Sports', 'Misc', 'Role-Playing', 'Shooter', 'Adventure',
#        'Racing', 'Platform', 'Simulation', 'Fighting', 'Strategy', 'Puzzle'],
#       dtype='object')

# %%
data.values
# Out:
# array([3316, 2346, 1739, 1488, 1310, 1286, 1249,  886,  867,  848,  681,
#         582])

# %% [markdown]
# # **Bentuk Visualisasi**

# %% [markdown]
# ## **Bar Chart**
#
# Bar chart bisa di buat dengan method bar. Bar chart berguna untuk memvisualisasikan frekuensi kejadian suatu data berdasarkan suatu kategori. Jadi, bar chart ini di visualisasikan untuk membandingkan data yang bertipe kategori. Bar chart berguna bila jumlah kategori tidak lebih dari 30 pada umumnya. Apabila lebih dari itu, biasanya bar chart akan menjadi kacau sehingga data sulit untuk di interpretasi.
#
# Berikut contoh sederhana dari visualisasi bar chart:

# %%
# import library
import pandas as pd
import matplotlib.pyplot as plt

# read data vgsales
df = pd.read_csv('https://drive.google.com/uc?id=1VdPQMY0LRgJhEPzCaGs0poAYDpAds--F')


# extract data tentang banyaknya setiap jenis genre dalam data
data = df['Genre'].value_counts()
category = data.index
frequency = data.values

# plot data
fig, ax = plt.subplots()
ax.bar(category, frequency)
ax.set_xticklabels(category, rotation=90)
plt.show()

# %% [markdown]
# Dari gambar di atas dapat di lihat bahwa data ini memiliki paling banyak data video games dengan genre Action, kemudian Sport, dan seterusnya.
#
# Method set_xticklabels() adalah untuk mengontrol komponen label data di sumbu x. di berikan label nya dengan data category, dan di putar sebesar 90 derajat agar label tidak bertumpuk.
#
# Pada bahasan selanjutnya akan di tunjukan improvisasi terhadap visualisasi ini.

# %% [markdown]
# **matplotlib.pyplot.bar**
#
# [source](https://matplotlib.org/3.2.2/api/_as_gen/matplotlib.pyplot.bar.html)
#
# `bar(x (label/position stick), height (y), width=0.8, bottom=None, *, align='center', data=None, **kwargs)`
#
# The bars are positioned at x with the given alignment. Their dimensions are given by width and height. The vertical baseline is bottom (default 0).
#
# Each of x, height, width, and bottom may either be a scalar applying to all bars, or it may be a sequence of length N providing a separate value for each bar.
#
# **Parameters:	**
#
# * x : sequence of scalars
#
#     The x coordinates of the bars. See also align for the alignment of the bars to the coordinates.
#
# * height : scalar or sequence of scalars
#
#     The height(s) of the bars.
#
# * width : scalar or array-like, optional
#
#     The width(s) of the bars (default: 0.8).
#
# * bottom : scalar or array-like, optional
#
#     The y coordinate(s) of the bars bases (default: 0).
#
# * align : {'center', 'edge'}, optional, default: 'center'
#
#     Alignment of the bars to the x coordinates:
#
#       1. 'center': Center the base on the x positions.
#       2. 'edge': Align the left edges of the bars with the x positions.
#
#     To align the bars on the right edge pass a negative width and align='edge'.
#
# **Other Parameters:**
#
# * color : scalar or array-like, optional
#
#     The colors of the bar faces.
#
# * edgecolor : scalar or array-like, optional
#
#     The colors of the bar edges.
#
# * linewidth : scalar or array-like, optional
#
#     Width of the bar edge(s). If 0, don't draw edges.
#
# * tick_label : string or array-like, optional
#
#     The tick labels of the bars. Default: None (Use default numeric labels.)
#
# * xerr, yerr : scalar or array-like of shape(N,) or shape(2,N), optional
#
#     If not None, add horizontal / vertical errorbars to the bar tips. The values are +/- sizes relative to the data:
#
#       1. scalar: symmetric +/- values for all bars
#
#       2. shape(N,): symmetric +/- values for each bar
#
#       3. shape(2,N): Separate - and + values for each bar. First row contains the lower errors, the second row contains the upper errors.
#
#       4. None: No errorbar. (Default)
#
#     See Different ways of specifying error bars for an example on the usage of xerr and yerr.
#
# * ecolor : scalar or array-like, optional, default: 'black'
#
#     The line color of the errorbars.
#
# * capsize : scalar, optional
#
#     The length of the error bar caps in points. Default: None, which will take the value from rcParams["errorbar.capsize"] = 0.0.
#
# * error_kw : dict, optional
#
#     Dictionary of kwargs to be passed to the errorbar method. Values of ecolor or capsize defined here take precedence over the independent kwargs.
#
# * log : bool, optional, default: False
#
#     If True, set the y-axis to be log scale.
#
# * orientation : {'vertical', 'horizontal'}, optional
#
#     This is for internal use only. Please use barh for horizontal bar plots. Default: 'vertical'.
#
#
# **Other optional kwargs:**
#
# ![line2d_01.png](https://raw.githubusercontent.com/nurimammasri/Wooky-Matplotlib/main/images/line2d_01.png)
#
# ![line2d_02.png](https://raw.githubusercontent.com/nurimammasri/Wooky-Matplotlib/main/images/line2d_02.png)

# %% [markdown]
# ### **Stacked Bar Graph**
#
# This is an example of creating a stacked bar plot with error bars using bar. Note the parameters `yerr` used for error bars, and `bottom` (for stacked) to stack the women's bars on top of the men's bars.

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 5
menMeans = (20, 35, 30, 35, 27)
womenMeans = (25, 32, 34, 20, 25)
menStd = (2, 3, 4, 1, 2)
womenStd = (3, 5, 2, 3, 3)
ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, menMeans, width, yerr=menStd)
p2 = plt.bar(ind, womenMeans, width,
             bottom=menMeans, yerr=womenStd)

plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.xticks(ind, ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.yticks(np.arange(0, 81, 10))
plt.legend((p1[0], p2[0]), ('Men', 'Women'))

plt.show()

# %% [markdown]
# ### **Grouped bar chart with labels**
#
# This example shows a how to create a grouped bar chart and how to annotate bars with labels.

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %% [markdown]
# ### **Horizontal bar chart**
#
# This example showcases a simple horizontal bar chart.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

ax.barh(y_pos, performance, xerr=error, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?')

plt.show()

# %% [markdown]
# ## **Scatter Plot**
#
# Scatter plot berguna untuk melakukan perbandingan data antara data bertipe numerik. untuk melakukan visualisasi scatter plot bisa dilakukan menggunakan method scatter().
#
# Contoh akan di visualisasikan dengan scatter plot data tentang penjualan semua video games di jepang dan Europa.

# %%
fig, ax = plt.subplots()

# pembuatan plot
ax.scatter(df['JP_Sales'], df['EU_Sales'], c='g')

# axis labeling
ax.set_xlabel('Penjualan di Jepang')
ax.set_ylabel('Penjualan di Europa')
ax.set_title('Penjualan Semua Video Games')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

x = np.linspace(0, 10, 100)
y = np.cos(x)

fig, ax = plt.subplots(figsize=(12,7))
ax.plot(x,y, marker='v', linestyle='None')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 7))
ax.scatter(x,y, marker='v', s=60)
plt.show()

# %%
rnd = np.random.RandomState(30)
x = rnd.randn(100)
y = rnd.randn(100)
color = rnd.randn(100)
sizes = 1000*rnd.randn(100)

fig, ax = plt.subplots(figsize=(12, 7))
mapbar =ax.scatter(x, y, c=color, s=sizes, alpha=0.5, cmap='summer')
fig.colorbar(mapbar)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/collections.py:885: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# ## **Histogram**
#
# Histogram mempunyai kemiripan dengan bar chart, beberapa keliru memahami bahwa bar chart sama dengan histogram. Kunci dari perbedaannya adalah Histogram untuk memvisualisasikan distribusi data dari suatu data bertipe numerik dan continues. sedangan bar chart untuk memvisualisasikan data bertipe kategori.
#
# Misalkan ingin mengetahui perbedaan distribusi penjualan video games di seluruh dunia untuk game bergenre Action dan Sport. Berikut adalah contoh visualisasi dari Histogram nya :

# %%
action = df[df['Genre']=='Action']['Global_Sales']
sport = df[df['Genre']=='Sports']['Global_Sales']

fig, ax = plt.subplots(ncols=2, figsize=(16, 8))
ax[0].hist(action, bins=50)
ax[0].set_xlabel('Penjualan Global Game Action')
ax[0].set_ylabel('Frekuensi')
ax[0].set_title('Distribusi Game Action Global')

ax[1].hist(sport, bins=50, color='g')
ax[1].set_xlabel('Penjualan Global Game Sports')
ax[1].set_ylabel('Frekuensi')
ax[1].set_title('Distribusi Penjualan Game Sports Global')
plt.show()

# %% [markdown]
# # **Perbandingan Kuantitatif**

# %% [markdown]
# ## **Perbandingan Kuantitatif Scatter Plot**
#
# Melakukan Perbandingan data Student Performance antara reading score dan writing score untuk male dan female

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('https://drive.google.com/uc?id=1qnJOohiX7Ji-CK1GNQ5uFxnp93HHf8G6')


df.head()
# Out:
#    gender race/ethnicity  ... reading score writing score
# 0  female        group B  ...            72            74
# 1  female        group C  ...            90            88
# 2  female        group B  ...            95            93
# 3    male        group A  ...            57            44
# 4    male        group C  ...            78            75
#
# [5 rows x 8 columns]

# %%
# scatter plot antara semua reading score dan writing score
fig, ax = plt.subplots(figsize=(12, 8))

ax.scatter(df['reading score'], df['writing score'])
plt.show()

# %%
# scatter plot antara reading score dan writing score male and female

fig, ax = plt.subplots(figsize=(12, 8))

rs_male = df['reading score'][df['gender']=='male']
ws_male = df['writing score'][df['gender']=='male']

rs_female = df['reading score'][df['gender']=='female']
ws_female = df['writing score'][df['gender']=='female']

ax.scatter(rs_male, ws_male, c='b', label='Male')
ax.scatter(rs_female, ws_female, c='y', label='Female')

ax.set_xlabel('Reading Score')
ax.set_ylabel('Writing Score')
ax.set_title('Student Performance')

plt.legend()

plt.show()

# %% [markdown]
# Menggunakan data pada c='' (color) sebagai parameter temperature terbaik.
#
# Melihat hungan antara reading score, writing terhadap nilai math score.

# %%
fig, ax = plt.subplots(figsize=(12, 8))

MS = df['math score']
RS = df['reading score']
WS = df['writing score']

axmap = ax.scatter(RS, WS, c=MS, cmap='PuBuGn')

ax.set_xlabel('Reading Score')
ax.set_ylabel('Writing Score')
ax.set_title('Student Performance')

fig.colorbar(axmap)
plt.show()

# %% [markdown]
# Dilihat bahwa jika reading score dan writing scorenya bagus maka akan bagus pula math score (di tunjukkan melalui color bar)

# %% [markdown]
# ## **Perbandingan Kuantitatif Bar Plot**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('https://drive.google.com/uc?id=1qnJOohiX7Ji-CK1GNQ5uFxnp93HHf8G6')


df.head()
# Out:
#    gender race/ethnicity  ... reading score writing score
# 0  female        group B  ...            72            74
# 1  female        group C  ...            90            88
# 2  female        group B  ...            95            93
# 3    male        group A  ...            57            44
# 4    male        group C  ...            78            75
#
# [5 rows x 8 columns]

# %%
mean_score = df.groupby('parental level of education').mean()
mean_score
# Out:
#                              math score  reading score  writing score
# parental level of education
# associate's degree            67.882883      70.927928      69.896396
# bachelor's degree             69.389831      73.000000      73.381356
# high school                   62.137755      64.704082      62.448980
# master's degree               69.745763      75.372881      75.677966
# some college                  67.128319      69.460177      68.840708
# some high school              63.497207      66.938547      64.888268

# %% [markdown]
# ## **Grouped Bar Chart with Labels**

# %%
fig, ax = plt.subplots(figsize=(12, 8))

x = mean_score.index
y = mean_score['math score']
y2 = mean_score['reading score']
y3 = mean_score['writing score']

ax.bar(x, y)
ax.bar(x, y2)
ax.bar(x, y3)

plt.show()

# %% [markdown]
# kita mau agar data yang di plot tidak berdempetan/bertumpukan, maka kita harus mengatur posisi tiap bar kita. dengan mengganti nilai `x` sebagai `index` untuk stick label dari string ke integer dengan np.arange() sebagai jaraka antar bar. kemudian mengganti nilai integer tersebut menggunakan set_xsticklabel() dengan string label index kembali.

# %%
x # ada 6 elemen
# Out:
# Index(['associate's degree', 'bachelor's degree', 'high school',
#        'master's degree', 'some college', 'some high school'],
#       dtype='object', name='parental level of education')

# %%
# np.arange(banyak label)
np.arange(6)
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
fig, ax = plt.subplots(figsize=(12, 8))

x = np.arange(6)
y = mean_score['math score']
y2 = mean_score['reading score']
y3 = mean_score['writing score']

ax.bar(x, y)
ax.bar(x, y2)
ax.bar(x, y3)

plt.show()

# %% [markdown]
# masih bertumpukan : ) karena posisi integernya sama. jika `x` di set secara manual dengan nilai integer.

# %%
fig, ax = plt.subplots(figsize=(12, 8))

x = np.arange(6)
y = mean_score['math score']
y2 = mean_score['reading score']
y3 = mean_score['writing score']

ax.bar([1,2,3,4,5,10], y)
ax.bar([1,2,3,4,5,8], y2)
ax.bar(x, y3)

plt.show()

# %% [markdown]
# dapat dilihat bahwa nilai integer menentuka letak tiap bar. Maka itu dapat digunakan untuk mengatur tiap posisi dari bar.

# %%
fig, ax = plt.subplots(figsize=(12, 8))

x = np.arange(6)
y = mean_score['math score']
y2 = mean_score['reading score']

ax.bar(x, y)
ax.bar(x+0.3, y2)

plt.show()

# %%
x # posisi normal setting posisi data
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
x+0.3 # memindahkan posisi bar pada point data tiap 0.3
# Out:
# array([0.3, 1.3, 2.3, 3.3, 4.3, 5.3])

# %%
fig, ax = plt.subplots(figsize=(12, 8))

x = np.arange(6)
y = mean_score['math score']
y2 = mean_score['reading score']


ax.bar(x, y2, width=0.3) # width sebagai lebar bar sebagai acuan untuk posisi bar
ax.bar(x+0.3, y)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 8))

x = np.arange(6)
y = mean_score['math score']
y2 = mean_score['reading score']
y3 = mean_score['writing score']

ax.bar(x, y, width=0.3)
ax.bar(x+0.3, y2, width=0.3)
ax.bar(x+2*0.3, y3, width=0.3)

plt.show()

# %% [markdown]
# Kita bisa memperbesar jarak antar kumpulan bar dari label. dengan mengubah posisi normal dari `x`

# %%
np.arange(6)
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
np.arange(0, 12, 2)
# Out:
# array([ 0,  2,  4,  6,  8, 10])

# %%
fig, ax = plt.subplots(figsize=(12, 8))

# x = np.arange(6) untuk memperlebar sebanyak 2 x maka (2*6) 6->banyak label
x= np.arange(0, 12, 2) # (fist, last(2*6), step)
y = mean_score['math score']
y2 = mean_score['reading score']
y3 = mean_score['writing score']

ax.bar(x, y, width=0.3)
ax.bar(x+0.3, y2, width=0.3)
ax.bar(x+2*0.3, y3, width=0.3)

plt.show()

# %% [markdown]
# Kemudian selanjutnya mengubah int label ke string label dari data.

# %%
mean_score.index
# Out:
# Index(['associate's degree', 'bachelor's degree', 'high school',
#        'master's degree', 'some college', 'some high school'],
#       dtype='object', name='parental level of education')

# %%
fig, ax = plt.subplots(figsize=(12, 8))

# x = np.arange(6) untuk memperlebar sebanyak 2 x maka (2*6) 6->banyak label
x= np.arange(0, 12, 2) # (fist, last(2*6), step)
y = mean_score['math score']
y2 = mean_score['reading score']
y3 = mean_score['writing score']

ax.bar(x, y, width=0.3)
ax.bar(x+0.3, y2, width=0.3)
ax.bar(x+2*0.3, y3, width=0.3)

ax.set_xticklabels(mean_score.index)

plt.show()

# %% [markdown]
# Dapat dilihat untuk label 'associate's degree' tidak ada. Karena ada pada point 0 sehingga tidak kelihatan. Caranya yakni dengan menambahkan label pada awal untuk menggeser label. `[0] + list(index)`

# %%
[0]+list(mean_score.index)
# Out:
# [0,
#  "associate's degree",
#  "bachelor's degree",
#  'high school',
#  "master's degree",
#  'some college',
#  'some high school']

# %%
fig, ax = plt.subplots(figsize=(12, 8))

# x = np.arange(6) untuk memperlebar sebanyak 2 x maka (2*6) 6->banyak label
x= np.arange(0, 12, 2) # (fist, last(2*6), step)
y = mean_score['math score']
y2 = mean_score['reading score']
y3 = mean_score['writing score']

ax.bar(x, y, width=0.3)
ax.bar(x+0.3, y2, width=0.3)
ax.bar(x+2*0.3, y3, width=0.3)

ax.set_xticklabels([0]+list(mean_score.index))

plt.show()

# %% [markdown]
# Menambahkan Label lagi

# %%
fig, ax = plt.subplots(figsize=(12, 8))

# x = np.arange(6) untuk memperlebar sebanyak 2 x maka (2*6) 6->banyak label
x= np.arange(0, 12, 2) # (fist, last(2*6), step)
y = mean_score['math score']
y2 = mean_score['reading score']
y3 = mean_score['writing score']

ax.bar(x, y, width=0.3, label='Math Score')
ax.bar(x+0.3, y2, width=0.3, label='Reading Score')
ax.bar(x+2*0.3, y3, width=0.3, label='Writing Score')

ax.set_ylabel('Score')
ax.set_xticklabels([0]+list(mean_score.index))

plt.legend()

plt.show()

# %% [markdown]
# ## **Stacked Bar Graph**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('https://drive.google.com/uc?id=1qnJOohiX7Ji-CK1GNQ5uFxnp93HHf8G6')


df.head()
# Out:
#    gender race/ethnicity  ... reading score writing score
# 0  female        group B  ...            72            74
# 1  female        group C  ...            90            88
# 2  female        group B  ...            95            93
# 3    male        group A  ...            57            44
# 4    male        group C  ...            78            75
#
# [5 rows x 8 columns]

# %%
mean_score = df.groupby('parental level of education').mean()
mean_score
# Out:
#                              math score  reading score  writing score
# parental level of education
# associate's degree            67.882883      70.927928      69.896396
# bachelor's degree             69.389831      73.000000      73.381356
# high school                   62.137755      64.704082      62.448980
# master's degree               69.745763      75.372881      75.677966
# some college                  67.128319      69.460177      68.840708
# some high school              63.497207      66.938547      64.888268

# %%
fig, ax = plt.subplots(figsize=(12, 8))

x= mean_score.index
y = mean_score['math score']
y2 = mean_score['reading score']
y3 = mean_score['writing score']

ax.bar(x, y)
ax.bar(x, y2)
ax.bar(x, y3)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 8))

x= mean_score.index
y = mean_score['math score']
y2 = mean_score['reading score']
y3 = mean_score['writing score']

ax.bar(x, y)
ax.bar(x, y2, bottom=y) # bottom 
ax.bar(x, y3, bottom=y2)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 8))

x= mean_score.index
y = mean_score['math score']
y2 = mean_score['reading score']
y3 = mean_score['writing score']

ax.bar(x, y, label='Math Score')
ax.bar(x, y2, bottom=y, label='Reading Score') # bottom = berada dibawah nilai bar pertama
ax.bar(x, y3, bottom=y+y2, label = 'Writing Score') # bottom = berada dibawah nilai bar pertama dan kedua

ax.set_xlabel('Pareltal Level of Educations')
ax.set_ylabel('Mean Score')

plt.legend()

plt.show()

# %% [markdown]
# # **Task**

# %% [markdown]
# Download [austin_weather.csv](https://drive.google.com/uc?export=download&id=10JkPB2hhDmkVUoCGFP6gpoRL1mvx0OPf)
#
# Github
#
# [austin_weather.csv](https://github.com/nurimammasri/Wooky-Matplotlib/blob/main/data/austin_weather.csv)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('https://drive.google.com/uc?id=1HlM0mS2m9jnhMoJ7iX-jIAykDBljPI3P')


df.head()
# Out:
#          Date  TempHighF  ...  PrecipitationSumInches               Events
# 0  2013-12-21         74  ...                    0.46  Rain , Thunderstorm
# 1  2013-12-22         56  ...                       0
# 2  2013-12-23         58  ...                       0
# 3  2013-12-24         61  ...                       0
# 4  2013-12-25         58  ...                       T
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        1319 non-null   object
#  1   TempHighF                   1319 non-null   int64
#  2   TempAvgF                    1319 non-null   int64
#  3   TempLowF                    1319 non-null   int64
#  4   DewPointHighF               1319 non-null   object
#  5   DewPointAvgF                1319 non-null   object
#  6   DewPointLowF                1319 non-null   object
#  7   HumidityHighPercent         1319 non-null   object
#  8   HumidityAvgPercent          1319 non-null   object
#  9   HumidityLowPercent          1319 non-null   object
#  10  SeaLevelPressureHighInches  1319 non-null   object
#  11  SeaLevelPressureAvgInches   1319 non-null   object
#  12  SeaLevelPressureLowInches   1319 non-null   object
# ...

# %% [markdown]
# <h2>Soal 1: Visualisasi Scatter Plot Perbandingan Kuantitatif</h2>
#
# Pada tugas kali ini kita akan mengamati nilai DewPointAvg (F) dengan mengamati nilai  HumidityAvg (%), TempAvg (F), dan WindAvg (MPG)
#
# Perhatikan bahwa data kita tidaklah siap untuk di analisis, salah satunya tipe data dari DewPointAvg (F), HumidityAvg (%), dan WindAvg (MPG) adalah object, padahalnya data nya ber isi numeric. maka :
# - Ubahlah tipe data tersebut menjadi tipe data float
#
# Kemudian:
#
# - Kalian tidak akan dengan mudah mengubah tipe data tersebut karena column tersebut mempunyai nilai '-' yang dimana tidak bisa di ubah ke bentuk float, maka replace lah terlebih dahulu data yang bernilai '-' dengan nilai NaN, gunakan method .replace(). baca dokumentasi https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.replace.html
# - Isi nilai nan dengan nilai sebelumnya di row tersebut. gunakan method .fillna() dengan argument method bernilai 'ffill', baca dokumentasi https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.fillna.html
# - Sekarang ubah tipe datanya dengan float, gunakan method .astype(), baca dokumentasi https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.astype.html
#
# Setelah ini sebagian data siap untuk di jadikan bahan analisis. maka:
#
# Buahlah visualisasi perbandingan kuantitatif scatter plot, sehingga menghasilkan gambar seperti dibawah:
#
# ket:
#
# - colormap adalah 'coolwarm'
# - berikat warna terhadap setiap data poin dengan nilai dari column TempAvgF
# - berikan size terhadap setiap data poin dengan nilai dari column WindAvgMPH, kalikan dengan 20 agar size terlihat lebih besar
#
#
# Berikan pendapat dari insight yang bisa di dapat dari visualisasi perbandingan kuantitatif ini!!!

# %% [markdown]
# ![soal01.png](https://raw.githubusercontent.com/nurimammasri/Wooky-Matplotlib/main/images/soal01.png)

# %%
# code here
def data_process(s):
  s.replace('-', np.nan, inplace=True)
  s.fillna(method='ffill', inplace=True)
  return s.astype('float')

df['DewPointAvgF'] = data_process(df['DewPointAvgF'])
df['HumidityAvgPercent'] = data_process(df['HumidityAvgPercent'])
df['TempAvgF'] = data_process(df['TempAvgF'])
df['WindAvgMPH'] = data_process(df['WindAvgMPH'])

fig, ax = plt.subplots(figsize=(14, 8))
austin_w = ax.scatter(df['HumidityAvgPercent'], df['DewPointAvgF'], c=df['DewPointAvgF'], cmap='coolwarm', s=df['WindAvgMPH']*20)
fig.colorbar(austin_w)

ax.set_xlabel('Humidity Avg %')
ax.set_ylabel('Dew Point Avg (F)')
ax.set_title('Austin Weather')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# Downoad  <a href="https://blog.sanbercode.com/wp-content/uploads/2020/05/vgsales.csv">vgsales.csv</a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# vgsales.csv
df = pd.read_csv('https://drive.google.com/uc?id=1bVfQKfCKEAEEr4khfWYDJvgUNPeDY26T')


df.head()
# Out:
#    Rank                      Name Platform  ...  JP_Sales Other_Sales Global_Sales
# 0     1                Wii Sports      Wii  ...      3.77        8.46        82.74
# 1     2         Super Mario Bros.      NES  ...      6.81        0.77        40.24
# 2     3            Mario Kart Wii      Wii  ...      3.79        3.31        35.82
# 3     4         Wii Sports Resort      Wii  ...      3.28        2.96        33.00
# 4     5  Pokemon Red/Pokemon Blue       GB  ...     10.22        1.00        31.37
#
# [5 rows x 11 columns]

# %% [markdown]
# <h2>Soal 2: Preparing Data</h2>
#
# Manipulasi data tersebut dengan menggroupkan berdasarkan Genre, kemudian ambil rata2 penjualan untuk setiap Region Kecuali Global_Sales berdasarkan kategori Genre.

# %%
#code here
sales = df.groupby('Genre')[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']].mean()
sales
# Out:
#               NA_Sales  EU_Sales  JP_Sales  Other_Sales
# Genre
# Action        0.264726  0.158323  0.048236     0.056508
# Adventure     0.082271  0.049868  0.040490     0.013072
# Fighting      0.263667  0.119481  0.103007     0.043255
# Misc          0.235906  0.124198  0.061967     0.043312
# Platform      0.504571  0.227573  0.147596     0.058228
# Puzzle        0.212680  0.087251  0.098471     0.021564
# Racing        0.287766  0.190865  0.045388     0.061865
# Role-Playing  0.219946  0.126384  0.236767     0.040060
# Shooter       0.444733  0.239137  0.029221     0.078389
# Simulation    0.211430  0.130773  0.073472     0.036355
# Sports        0.291283  0.160635  0.057702     0.057532
# Strategy      0.100881  0.066579  0.072628     0.016681

# %% [markdown]
# Expected Output:
#
# ![soal02.png](https://raw.githubusercontent.com/nurimammasri/Wooky-Matplotlib/main/images/soal02.png)

# %% [markdown]
# ---

# %% [markdown]
# <h2>Soal 3: Perbandingan Kuantitatif Barplot - Grouping Visualisasi Dengan Barplot</h2>
#
# 1. Visualisasikan gambar yang tadi kita manipulasi, untuk menghasilkan visualisasi seperti di bawah ini
# 2. Tuliskan apa insight yang bisa kamu dapat dari visualisasi tersebut

# %%
fig.legend?

# %%
#code here
plt.style.use('ggplot')
fig, ax = plt.subplots(figsize=(20,9))

x = np.arange(0, 12, 3)
width= 0

for row in sales.iterrows():
  ax.bar(x+width, row[1], label=row[0], width=0.2)
  width=width+0.2

ax.set_xticks(x+1)
ax.set_xticklabels(sales.columns)

ax.set_xlabel('Region Sales')
ax.set_ylabel('Mean Sales')
ax.set_title('Mean Sales Video Games By Genre')

fig.legend(frameon=True, bbox_to_anchor=(1.02, 1.01), loc='upper right')
plt.tight_layout()

plt.show()

# %% [markdown]
# Jawab:
#
# Dapat terlihat bahwa Rata Rata Tertinggi Penjualan :
#
# * NA_Sales = Kategori Platform
# * EU_Sales = Kategori Shooter
# * JP_Sales = Kategori Role Playing
# * Other_Sales = Kategori Shooter

# %% [markdown]
# Expected Output:
#
# ![soal03.png](https://raw.githubusercontent.com/nurimammasri/Wooky-Matplotlib/main/images/soal03.png)

# %% [markdown]
# <h2>Soal 4: Perbandingan Kuantitatif Barplot - Stack Barplot</h2>
#
# 1. Visualisasikan gambar yang tadi kita manipulasi, untuk menhasilkan visualisasi seperti di bawah ini
# 2. Tuliskan apa insight yang bisa kamu dapat dari visualisasi tersebut

# %%
#code here

#code here
plt.style.use('ggplot')
fig, ax = plt.subplots(figsize=(16,8))

x = np.arange(4)
bt = [0, 0, 0, 0]

for row in sales.iterrows():
  ax.bar(x, row[1], label=row[0], bottom = bt)
  bt=bt+row[1]

ax.set_xticks(x)
ax.set_xticklabels(sales.columns)

ax.set_xlabel('Region Sales')
ax.set_ylabel('Mean Sales')
ax.set_title('Mean Sales Video Games By Genre')
fig.legend(frameon=True, bbox_to_anchor=(1.02, 1.05), loc='upper right')
plt.tight_layout()

plt.show()

# %% [markdown]
# Jawab:
#
# Dapat terlihat bahwa Rata Rata Tertinggi Penjualan :
#
# * NA_Sales = Kategori Platform
# * EU_Sales = Kategori Shooter
# * JP_Sales = Kategori Role Playing
# * Other_Sales = Kategori Shooter

# %% [markdown]
# Expected Output:
#
# ![soal04.png](https://raw.githubusercontent.com/nurimammasri/Wooky-Matplotlib/main/images/soal04.png)
